# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time

from sklearn import datasets, decomposition, manifold, preprocessing
from colorsys import hsv_to_rgb

import umap

sns.set(context="paper", style="white")


fmnist, fmnist_labels = fetch_openml(data_id=40996)
digits, digits_labels = datasets.load_digits
shuttle, shuttle_labels = fetch_openml(data_id=40685)
mnist, mnist_labels = fetch_openml("mnist_784", version=1)


UMAP = umap.UMAP(n_components=2)
TSNE= manifold.TSNE(n_components=2)
SVD = decomposition.TruncatedSVD(n_components=2)
PCA = decomposition.PCA(n_components=2)

reducers = [
    UMAP,
    TSNE,
    SVD,
    PCA,
]

test_data = [
    (fmnist, fmnist_labels),
    (digits, digits_labels),
    (shuttle, shuttle_labels),
    (mnist, mnist_labels),
]
dataset_names = ["Fmnist", "Digits", "Shuttle", "Mnist"]

# %%
fig, axs = plt.subplots(4, 4, figsize=(16, 16))
for model in reducers:
    for data, labels in test_data: 
        embeddings = model.fit_transform(data)
      
        color = labels.target.astype(int)
        plt.scatter(embedding[:, 0], embedding[:, 1], c=color)
        plt.setp(ax, xticks=[], yticks=[])

plt.show()
# Out:
# C:\Users\User\anaconda3\envs\tf\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\User\anaconda3\envs\tf\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# C:\Users\User\anaconda3\envs\tf\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\User\anaconda3\envs\tf\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# C:\Users\User\anaconda3\envs\tf\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# ...
